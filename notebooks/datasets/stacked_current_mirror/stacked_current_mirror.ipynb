# %%
import os
os.environ['PATH'] = '/home/irman/Gelochip/.venv/bin:' + os.environ.get('PATH', '')
import sys, os
os.environ.setdefault('PDK_ROOT', os.path.expanduser('~/pdks'))
sys.path.insert(0, '/home/irman/Gelochip/src/gelochip')

import klayout.db as kdb
import klayout.lay as klay
from IPython.display import Image, display

def show_gds(gds_path, out_png=None, width=1600, height=900):
    gds_abs = os.path.abspath(gds_path)
    if not os.path.exists(gds_abs):
        print(f'GDS not found: {gds_abs}'); return
    out_png = out_png or gds_abs.replace('.gds', '_preview.png')
    lv = klay.LayoutView()
    lv.load_layout(gds_abs, True)
    lv.max_hier(); lv.zoom_fit()
    lv.save_image(out_png, width, height)
    display(Image(out_png))

# %%
import sys
try:
    cm_mod = sys.modules['glayout.cells.elementary.current_mirror.current_mirror']
    if not hasattr(cm_mod, 'orig_cmn'):
        orig_cmn = cm_mod.current_mirror_netlist
        cm_mod.orig_cmn = orig_cmn
        def patched_cmn(pdk, width, length, multipliers, fingers=1, **kwargs):
            netlist = orig_cmn(pdk, width=width, length=length, multipliers=multipliers, fingers=fingers, **kwargs)
            if 'B' in netlist.nodes:
                idx = netlist.nodes.index('B')
                netlist.nodes[idx] = 'VB'
            if 'VOUT' in netlist.nodes:
                idx = netlist.nodes.index('VOUT')
                netlist.nodes[idx] = 'VCOPY'
            return netlist
        cm_mod.current_mirror_netlist = patched_cmn
        for modname, mod in list(sys.modules.items()):
            if hasattr(mod, 'current_mirror_netlist'):
                setattr(mod, 'current_mirror_netlist', patched_cmn)
except Exception as e:
    pass

from glayout import MappedPDK
from glayout.pdk.gf180_mapped import gf180_mapped_pdk
from gdsfactory.cell import cell, clear_cache
from gdsfactory.component import Component, copy
from gdsfactory.component_reference import ComponentReference
from gdsfactory.components.rectangle import rectangle
from typing import Optional, Union
from glayout.primitives.fet import nmos, pmos, multiplier
from glayout.cells.elementary.diff_pair import diff_pair
from glayout.primitives.guardring import tapring
from glayout.primitives.mimcap import mimcap_array, mimcap
from glayout.routing import c_route,L_route,straight_route
from glayout.primitives.via_gen import via_stack, via_array
from gdsfactory.routing.route_quad import route_quad
from glayout.util.comp_utils import evaluate_bbox, prec_ref_center, movex, movey, to_decimal, to_float, move, align_comp_to_port, get_padding_points_cc
from glayout.util.port_utils import rename_ports_by_orientation, rename_ports_by_list, add_ports_perimeter, print_ports, set_port_orientation, rename_component_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.placement.two_transistor_interdigitized import two_nfet_interdigitized
from glayout.spice import Netlist


def stacked_nfet_current_mirror(pdk: MappedPDK, half_common_source_nbias: tuple[float, float, int, int], rmult: int, sd_route_left: bool) -> Component:
    cmirror_output = nmos(
        pdk,
        width=half_common_source_nbias[0],
        length=half_common_source_nbias[1],
        fingers=half_common_source_nbias[2],
        multipliers=half_common_source_nbias[3],
        with_tie=True,
        with_dnwell=False,
        with_substrate_tap=False,
        with_dummy=True,
        sd_route_left = sd_route_left,
        rmult=rmult,
        tie_layers=("met2","met2")
    )
    cmirrorref = nmos(
        pdk,
        width=half_common_source_nbias[0],
        length=half_common_source_nbias[1],
        fingers=half_common_source_nbias[2],
        multipliers=1,
        with_tie=True,
        with_dnwell=False,
        with_substrate_tap=False,
        with_dummy=True,
        sd_route_left = sd_route_left,
        rmult=rmult,
        tie_layers=("met2","met2")
    )
    cmirrorref_ref = prec_ref_center(cmirrorref)
    cmirrorout_ref = prec_ref_center(cmirror_output)
    return cmirrorref_ref, cmirrorout_ref

# Create and evaluate a current mirror instance
if __name__ == "__main__":
    ref, out = stacked_nfet_current_mirror(
        pdk=gf180_mapped_pdk,
        half_common_source_nbias=(0.5, 0.15, 4, 4),
        rmult=2,
        sd_route_left=True
    )
    cm = Component()
    cm.add(ref)
    cm.add(out)
    pass # cm.show()
    cm_gds = cm.write_gds("stacked_nfet_current_mirror.gds")


# Show the generated GDS
show_gds("stacked_nfet_current_mirror.gds")

comp = cm
comp.name = 'stacked_nfet_current_mirror'
# DRC with magic (graceful if magic not installed)
try:
    drc_result = gf180_mapped_pdk.drc_magic(comp, comp.name)
    print('DRC:', drc_result)
except Exception as e:
    print(f'DRC skipped: {e}')
# LVS with netgen (graceful if netgen not installed)
try:
    lvs_result = gf180_mapped_pdk.lvs_netgen(comp, comp.name)
    print('LVS:', lvs_result['result_str'])
except Exception as e:
    print(f'LVS skipped: {e}')
# Out:
# 2026-05-18 20:37:58.720 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active
# /tmp/ipykernel_22094/3729647606.py:89: UserWarning: Unnamed cells, 3 in 'Unnamed_d731f990'
#   cm_gds = cm.write_gds("stacked_nfet_current_mirror.gds")
# 2026-05-18 20:38:01.320 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to 'stacked_nfet_current_mirror.gds'
# /home/irman/Gelochip/src/gelochip/glayout/pdk/mappedpdk.py:538: UserWarning: Unnamed cells, 2 in 'stacked_nfet_current_mirror'
#   layout.write_gds(gds_path)
# 2026-05-18 20:38:01.393 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmph05clhy0/stacked_nfet_current_mirror.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
# /home/irman/Gelochip/src/gelochip/glayout/pdk/mappedpdk.py:762: UserWarning: Unnamed cells, 2 in 'stacked_nfet_current_mirror'
#   layout.write_gds(str(gds_path))
# 2026-05-18 20:38:01.622 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpui2g4a7b/stacked_nfet_current_mirror.gds'
# Magic 8.3 revision 644 - Compiled on Sun May 17 10:32:25 PM WIB 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmph05clhy0/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "stacked_nfet_current_mirror".
# Reading "Unnamed_9aea5573".
# Reading "Unnamed_8e719756".
# [INFO]: Loading stacked_nfet_current_mirror
#
# Loading DRC CIF style.
# [INFO]: DONE with /tmp/tmph05clhy0/stacked_nfet_current_mirror.rpt
#
# Using technology "gf180mcuD", version 1.0.493-0-g0fe599b
#
# stacked_nfet_current_mirror count:
#
# ----------------------------------------
#
# Metal2 spacing < 0.28um (M2.2a)
#
# ----------------------------------------
#
#  -2.810um 2.350um 2.530um 2.475um
#
#  -2.810um 2.240um 2.530um 2.350um
#
#  -2.530um -0.105um 2.530um 0.130um
#
#  -3.630um -2.340um -3.520um -2.305um
#
#  -3.520um -2.340um -3.240um -2.305um
#
#  -3.240um -2.340um 2.530um -2.305um
#
#  -3.630um -2.450um 2.530um -2.340um
#
# ----------------------------------------
#
# This layer can't abut or partially overlap between subcells
#
# ----------------------------------------
#
#  -2.515um 2.720um -2.285um 2.950um
#
#  -2.285um 2.870um -2.270um 2.950um
#
#  -2.515um 2.720um -2.285um 2.950um
#
#  -2.530um 2.705um -2.150um 2.720um
#
#  -2.530um 2.870um -2.270um 2.965um
#
#  -2.530um 2.705um -2.150um 2.870um
#
#  -0.130um 2.720um -0.115um 2.950um
#
#  -0.115um 2.720um 0.115um 2.950um
#
#  0.115um 2.720um 0.130um 2.950um
#
#  -0.130um 2.610um 0.130um 2.965um
#
#  2.285um 2.720um 2.515um 2.950um
#
#  2.150um 2.705um 2.530um 2.720um
#
#  2.270um 2.870um 2.285um 2.950um
#
#  2.285um 2.720um 2.515um 2.950um
#
#  2.150um 2.705um 2.530um 2.870um
#
#  2.270um 2.870um 2.530um 2.965um
#
#  -1.270um 1.555um -1.010um 1.825um
#
#  -1.270um 1.310um -1.010um 1.825um
#
#  1.010um 1.555um 1.270um 1.825um
#
#  1.010um 1.310um 1.270um 1.825um
#
#  -1.270um -0.790um -1.010um -0.520um
#
#  -1.270um -1.035um -1.010um -0.520um
#
#  1.010um -0.790um 1.270um -0.520um
#
#  1.010um -1.035um 1.270um -0.520um
#
#  -1.850um -3.000um -1.570um -2.760um
#
#  -0.710um -3.000um -0.430um -2.760um
#
#  0.430um -3.000um 0.710um -2.760um
#
#  1.570um -3.000um 1.850um -2.760um
#
#  -2.285um 2.720um -2.150um 2.870um
#
#  -2.530um 2.705um -2.150um 2.720um
#
#  -2.530um 2.705um -2.150um 2.870um
#
#  -2.410um 2.610um -2.150um 2.705um
#
#  -2.285um 2.720um -2.150um 2.870um
#
#  -2.530um 2.705um -2.150um 2.720um
#
#  -2.410um 2.610um -2.150um 2.705um
#
#  -2.530um 2.705um -2.150um 2.870um
#
#  -0.130um 2.610um 0.130um 2.720um
#
#  -0.130um 2.610um 0.130um 2.965um
#
#  2.150um 2.720um 2.285um 2.870um
#
#  2.150um 2.705um 2.530um 2.720um
#
#  2.150um 2.705um 2.530um 2.870um
#
#  2.150um 2.610um 2.410um 2.705um
#
#  2.150um 2.720um 2.285um 2.870um
#
#  2.150um 2.705um 2.530um 2.720um
#
#  2.150um 2.610um 2.410um 2.705um
#
#  2.150um 2.705um 2.530um 2.870um
#
#  -1.270um 1.555um -1.010um 1.825um
#
#  -1.270um 1.310um -1.010um 1.825um
#
#  1.010um 1.555um 1.270um 1.825um
#
#  1.010um 1.310um 1.270um 1.825um
#
#  -1.270um -0.790um -1.010um -0.520um
#
#  -1.270um -1.035um -1.010um -0.520um
#
#  1.010um -0.790um 1.270um -0.520um
#
#  1.010um -1.035um 1.270um -0.520um
#
# ----------------------------------------
#
# Via1 width < 0.26um (V1.1)
#
# ----------------------------------------
#
#  -2.270um 2.870um -2.150um 2.965um
#
#  2.150um 2.870um 2.270um 2.965um
#
# ----------------------------------------
#
# Can't overlap those layers
#
# ----------------------------------------
#
#  -4.470um -3.000um -4.190um -2.760um
#
#  -1.850um -3.000um -1.570um -2.760um
#
#  -0.710um -3.000um -0.430um -2.760um
#
#  0.430um -3.000um 0.710um -2.760um
#
#  1.570um -3.000um 1.850um -2.760um
#
#  4.190um -3.000um 4.470um -2.760um
#
#  -5.200um -3.015um -3.460um -3.000um
#
#  -2.600um -3.015um 2.600um -3.000um
#
#  3.460um -3.015um 5.200um -3.000um
#
# ----------------------------------------
#
# Via1 spacing < 0.26um (V1.2a)
#
# ----------------------------------------
#
#  -6.200um 1.885um -6.185um 1.990um
#
#  -6.185um 1.885um -5.955um 1.990um
#
#  -5.955um 1.885um -5.940um 1.990um
#
#  -6.200um 1.870um -5.940um 1.885um
#
#  -6.200um 1.485um -6.185um 1.590um
#
#  -6.185um 1.485um -5.955um 1.590um
#
#  -5.955um 1.485um -5.940um 1.590um
#
#  -6.200um 1.470um -5.940um 1.485um
#
#  5.940um 1.885um 5.955um 1.990um
#
#  5.955um 1.885um 6.185um 1.990um
#
#  6.185um 1.885um 6.200um 1.990um
#
#  5.940um 1.870um 6.200um 1.885um
#
#  -6.200um 1.085um -6.185um 1.190um
#
#  -6.185um 1.085um -5.955um 1.190um
#
#  -5.955um 1.085um -5.940um 1.190um
#
#  -6.200um 1.070um -5.940um 1.085um
#
#  5.940um 1.485um 5.955um 1.590um
#
#  5.955um 1.485um 6.185um 1.590um
#
#  6.185um 1.485um 6.200um 1.590um
#
#  5.940um 1.470um 6.200um 1.485um
#
#  5.940um 1.085um 5.955um 1.190um
#
#  5.955um 1.085um 6.185um 1.190um
#
#  6.185um 1.085um 6.200um 1.190um
#
#  5.940um 1.070um 6.200um 1.085um
#
#  -6.200um 0.685um -6.185um 0.790um
#
#  -6.185um 0.685um -5.955um 0.790um
#
#  -5.955um 0.685um -5.940um 0.790um
#
#  -6.200um 0.670um -5.940um 0.685um
#
#  -6.200um 0.285um -6.185um 0.390um
#
#  -6.185um 0.285um -5.955um 0.390um
#
#  -5.955um 0.285um -5.940um 0.390um
#
#  -6.200um 0.270um -5.940um 0.285um
#
#  -0.390um 0.525um -0.270um 0.530um
#
#  -0.130um 0.270um -0.010um 0.285um
#
#  -0.130um 0.285um -0.010um 0.515um
#
#  -0.130um 0.515um -0.010um 0.525um
#
#  0.270um 0.515um 0.390um 0.530um
#
#  0.270um 0.285um 0.285um 0.515um
#
#  0.285um 0.285um 0.390um 0.515um
#
#  0.270um 0.270um 0.390um 0.285um
#
#  5.940um 0.685um 5.955um 0.790um
#
#  5.955um 0.685um 6.185um 0.790um
#
#  6.185um 0.685um 6.200um 0.790um
#
#  5.940um 0.670um 6.200um 0.685um
#
#  -6.200um -0.115um -6.185um -0.010um
#
#  -6.185um -0.115um -5.955um -0.010um
#
#  -5.955um -0.115um -5.940um -0.010um
#
#  -6.200um -0.130um -5.940um -0.115um
#
#  -6.200um -0.515um -6.185um -0.410um
#
#  -6.185um -0.515um -5.955um -0.410um
#
#  -5.955um -0.515um -5.940um -0.410um
#
#  -6.200um -0.530um -5.940um -0.515um
#
#  -6.200um -0.915um -6.185um -0.810um
#
#  -6.185um -0.915um -5.955um -0.810um
#
#  -5.955um -0.915um -5.940um -0.810um
#
#  -6.200um -0.930um -5.940um -0.915um
#
#  5.940um 0.285um 5.955um 0.390um
#
#  5.955um 0.285um 6.185um 0.390um
#
#  6.185um 0.285um 6.200um 0.390um
#
#  5.940um 0.270um 6.200um 0.285um
#
#  5.940um -0.115um 5.955um -0.010um
#
#  5.955um -0.115um 6.185um -0.010um
#
#  6.185um -0.115um 6.200um -0.010um
#
#  5.940um -0.130um 6.200um -0.115um
#
#  -6.200um -1.315um -6.185um -1.210um
#
#  -6.185um -1.315um -5.955um -1.210um
#
#  -5.955um -1.315um -5.940um -1.210um
#
#  -6.200um -1.330um -5.940um -1.315um
#
#  5.940um -0.515um 5.955um -0.410um
#
#  5.955um -0.515um 6.185um -0.410um
#
#  6.185um -0.515um 6.200um -0.410um
#
#  5.940um -0.530um 6.200um -0.515um
#
#  5.940um -0.915um 5.955um -0.810um
#
#  5.955um -0.915um 6.185um -0.810um
#
#  6.185um -0.915um 6.200um -0.810um
#
#  5.940um -0.930um 6.200um -0.915um
#
#  5.940um -1.315um 5.955um -1.210um
#
#  5.955um -1.315um 6.185um -1.210um
#
#  6.185um -1.315um 6.200um -1.210um
#
#  5.940um -1.330um 6.200um -1.315um
#
#  -6.200um -1.715um -6.185um -1.610um
#
#  -6.185um -1.715um -5.955um -1.610um
#
#  -5.955um -1.715um -5.940um -1.610um
#
#  -6.200um -1.730um -5.940um -1.715um
#
#  -0.390um -1.820um -0.270um -1.815um
#
#  -0.130um -2.075um -0.010um -2.060um
#
#  -0.130um -2.060um -0.010um -1.830um
#
#  -0.130um -1.830um -0.010um -1.820um
#
#  0.270um -1.830um 0.390um -1.815um
#
#  0.270um -2.060um 0.285um -1.830um
#
#  0.285um -2.060um 0.390um -1.830um
#
#  0.270um -2.075um 0.390um -2.060um
#
#  5.940um -1.715um 5.955um -1.610um
#
#  5.955um -1.715um 6.185um -1.610um
#
#  6.185um -1.715um 6.200um -1.610um
#
#  5.940um -1.730um 6.200um -1.715um
#
#  -2.530um -2.950um -2.515um -2.860um
#
#  -2.515um -2.950um -2.285um -2.860um
#
#  -2.285um -2.950um -2.270um -2.860um
#
#  -2.530um -2.965um -2.270um -2.950um
#
#  -1.530um -2.965um -1.470um -2.950um
#
#  -0.930um -2.950um -0.915um -2.860um
#
#  -0.915um -2.950um -0.750um -2.860um
#
#  -0.930um -2.965um -0.750um -2.950um
#
#  -0.130um -2.950um -0.115um -2.860um
#
#  -0.115um -2.950um 0.115um -2.860um
#
#  0.115um -2.950um 0.130um -2.860um
#
#  -0.130um -2.965um 0.130um -2.950um
#
#  0.750um -2.950um 0.915um -2.860um
#
#  0.915um -2.950um 0.930um -2.860um
#
#  0.750um -2.965um 0.930um -2.950um
#
#  1.470um -2.965um 1.530um -2.950um
#
#  2.270um -2.950um 2.285um -2.860um
#
#  2.285um -2.950um 2.410um -2.860um
#
#  2.270um -2.965um 2.410um -2.950um
#
#  2.410um -2.950um 2.515um -2.860um
#
#  2.515um -2.950um 2.530um -2.860um
#
#  2.410um -2.965um 2.530um -2.950um
#
#  -6.200um 1.885um -6.185um 1.990um
#
#  -6.185um 1.885um -5.955um 1.990um
#
#  -5.955um 1.885um -5.940um 1.990um
#
#  -6.200um 1.870um -5.940um 1.885um
#
#  -6.200um 1.485um -6.185um 1.590um
#
#  -6.185um 1.485um -5.955um 1.590um
#
#  -5.955um 1.485um -5.940um 1.590um
#
#  -6.200um 1.470um -5.940um 1.485um
#
#  5.940um 1.885um 5.955um 1.990um
#
#  5.955um 1.885um 6.185um 1.990um
#
#  6.185um 1.885um 6.200um 1.990um
#
#  5.940um 1.870um 6.200um 1.885um
#
#  5.940um 1.485um 5.955um 1.590um
#
#  5.955um 1.485um 6.185um 1.590um
#
#  6.185um 1.485um 6.200um 1.590um
#
#  5.940um 1.470um 6.200um 1.485um
#
#  -6.200um 1.085um -6.185um 1.190um
#
#  -6.185um 1.085um -5.955um 1.190um
#
#  -5.955um 1.085um -5.940um 1.190um
#
#  -6.200um 1.070um -5.940um 1.085um
#
#  5.940um 1.085um 5.955um 1.190um
#
#  5.955um 1.085um 6.185um 1.190um
#
#  6.185um 1.085um 6.200um 1.190um
#
#  5.940um 1.070um 6.200um 1.085um
#
#  -6.200um 0.685um -6.185um 0.790um
#
#  -6.185um 0.685um -5.955um 0.790um
#
#  -5.955um 0.685um -5.940um 0.790um
#
#  -6.200um 0.670um -5.940um 0.685um
#
#  -6.200um 0.285um -6.185um 0.390um
#
#  -6.185um 0.285um -5.955um 0.390um
#
#  -5.955um 0.285um -5.940um 0.390um
#
#  -6.200um 0.270um -5.940um 0.285um
#
#  -0.390um 0.525um -0.270um 0.530um
#
#  -0.130um 0.270um -0.010um 0.525um
#
#  0.270um 0.515um 0.390um 0.530um
#
#  0.270um 0.285um 0.285um 0.515um
#
#  0.285um 0.285um 0.390um 0.515um
#
#  0.270um 0.270um 0.390um 0.285um
#
#  5.940um 0.685um 5.955um 0.790um
#
#  5.955um 0.685um 6.185um 0.790um
#
#  6.185um 0.685um 6.200um 0.790um
#
#  5.940um 0.670um 6.200um 0.685um
#
#  5.940um 0.285um 5.955um 0.390um
#
#  5.955um 0.285um 6.185um 0.390um
#
#  6.185um 0.285um 6.200um 0.390um
#
#  5.940um 0.270um 6.200um 0.285um
#
#  -6.200um -0.115um -6.185um -0.010um
#
#  -6.185um -0.115um -5.955um -0.010um
#
#  -5.955um -0.115um -5.940um -0.010um
#
#  -6.200um -0.130um -5.940um -0.115um
#
#  -6.200um -0.515um -6.185um -0.410um
#
#  -6.185um -0.515um -5.955um -0.410um
#
#  -5.955um -0.515um -5.940um -0.410um
#
#  -6.200um -0.530um -5.940um -0.515um
#
#  -6.200um -0.915um -6.185um -0.810um
#
#  -6.185um -0.915um -5.955um -0.810um
#
#  -5.955um -0.915um -5.940um -0.810um
#
#  -6.200um -0.930um -5.940um -0.915um
#
#  5.940um -0.115um 5.955um -0.010um
#
#  5.955um -0.115um 6.185um -0.010um
#
#  6.185um -0.115um 6.200um -0.010um
#
#  5.940um -0.130um 6.200um -0.115um
#
#  5.940um -0.515um 5.955um -0.410um
#
#  5.955um -0.515um 6.185um -0.410um
#
#  6.185um -0.515um 6.200um -0.410um
#
#  5.940um -0.530um 6.200um -0.515um
#
#  5.940um -0.915um 5.955um -0.810um
#
#  5.955um -0.915um 6.185um -0.810um
#
#  6.185um -0.915um 6.200um -0.810um
#
#  5.940um -0.930um 6.200um -0.915um
#
#  -6.200um -1.315um -6.185um -1.210um
#
#  -6.185um -1.315um -5.955um -1.210um
#
#  -5.955um -1.315um -5.940um -1.210um
#
#  -6.200um -1.330um -5.940um -1.315um
#
#  -6.200um -1.715um -6.185um -1.610um
#
#  -6.185um -1.715um -5.955um -1.610um
#
#  -5.955um -1.715um -5.940um -1.610um
#
#  -6.200um -1.730um -5.940um -1.715um
#
#  -0.390um -1.820um -0.270um -1.815um
#
#  -0.130um -2.075um -0.010um -1.820um
#
#  0.270um -1.830um 0.390um -1.815um
#
#  0.270um -2.060um 0.285um -1.830um
#
#  0.285um -2.060um 0.390um -1.830um
#
#  0.270um -2.075um 0.390um -2.060um
#
#  5.940um -1.315um 5.955um -1.210um
#
#  5.955um -1.315um 6.185um -1.210um
#
#  6.185um -1.315um 6.200um -1.210um
#
#  5.940um -1.330um 6.200um -1.315um
#
#  5.940um -1.715um 5.955um -1.610um
#
#  5.955um -1.715um 6.185um -1.610um
#
#  6.185um -1.715um 6.200um -1.610um
#
#  5.940um -1.730um 6.200um -1.715um
#
#  -2.530um -2.950um -2.515um -2.860um
#
#  -2.515um -2.950um -2.285um -2.860um
#
#  -2.285um -2.950um -2.270um -2.860um
#
#  -2.530um -2.965um -2.270um -2.950um
#
#  -1.530um -2.965um -1.470um -2.950um
#
#  -0.930um -2.950um -0.915um -2.860um
#
#  -0.915um -2.950um -0.750um -2.860um
#
#  -0.930um -2.965um -0.750um -2.950um
#
#  -0.130um -2.950um -0.115um -2.860um
#
#  -0.115um -2.950um 0.115um -2.860um
#
#  0.115um -2.950um 0.130um -2.860um
#
#  -0.130um -2.965um 0.130um -2.950um
#
#  0.750um -2.950um 0.915um -2.860um
#
#  0.915um -2.950um 0.930um -2.860um
#
#  0.750um -2.965um 0.930um -2.950um
#
#  1.470um -2.965um 1.530um -2.950um
#
#  2.270um -2.950um 2.285um -2.860um
#
#  2.285um -2.950um 2.410um -2.860um
#
#  2.270um -2.965um 2.410um -2.950um
#
#  2.410um -2.950um 2.515um -2.860um
#
#  2.515um -2.950um 2.530um -2.860um
#
#  2.410um -2.965um 2.530um -2.950um
#
# ----------------------------------------
#
# Diffusion contact spacing < 0.24um (CO.2a - 2 * CO.6)
#
# ----------------------------------------
#
#  -6.185um 1.885um -5.955um 1.955um
#
#  5.955um 1.885um 6.185um 1.955um
#
#  -6.185um 1.485um -5.955um 1.555um
#
#  5.955um 1.485um 6.185um 1.555um
#
#  -6.185um 1.085um -5.955um 1.155um
#
#  -6.185um 0.685um -5.955um 0.755um
#
#  -6.185um 0.285um -5.955um 0.355um
#
#  5.955um 1.085um 6.185um 1.155um
#
#  5.955um 0.685um 6.185um 0.755um
#
#  -6.185um -0.115um -5.955um -0.045um
#
#  5.955um 0.285um 6.185um 0.355um
#
#  5.955um -0.115um 6.185um -0.045um
#
#  -6.185um -0.515um -5.955um -0.445um
#
#  -6.185um -0.915um -5.955um -0.845um
#
#  5.955um -0.515um 6.185um -0.445um
#
#  5.955um -0.915um 6.185um -0.845um
#
#  -6.185um -1.315um -5.955um -1.245um
#
#  -6.185um -1.715um -5.955um -1.645um
#
#  5.955um -1.315um 6.185um -1.245um
#
#  5.955um -1.715um 6.185um -1.645um
#
#  -4.915um -2.950um -4.785um -2.895um
#
#  -4.785um -2.950um -4.685um -2.895um
#
#  -4.115um -2.950um -3.885um -2.895um
#
#  -2.515um -2.950um -2.285um -2.895um
#
#  -0.915um -2.950um -0.785um -2.895um
#
#  -0.115um -2.950um 0.115um -2.895um
#
#  0.785um -2.950um 0.915um -2.895um
#
#  2.285um -2.950um 2.395um -2.895um
#
#  2.395um -2.950um 2.515um -2.895um
#
#  3.885um -2.950um 4.115um -2.895um
#
#  4.685um -2.950um 4.915um -2.895um
#
#  -6.185um 1.885um -5.955um 1.955um
#
#  -6.185um 1.885um -5.955um 1.955um
#
#  -6.185um 1.485um -5.955um 1.555um
#
#  -6.185um 1.485um -5.955um 1.555um
#
#  -6.185um 1.085um -5.955um 1.155um
#
#  -6.185um 1.085um -5.955um 1.155um
#
#  5.955um 1.885um 6.185um 1.955um
#
#  5.955um 1.885um 6.185um 1.955um
#
#  5.955um 1.485um 6.185um 1.555um
#
#  5.955um 1.485um 6.185um 1.555um
#
#  5.955um 1.085um 6.185um 1.155um
#
#  5.955um 1.085um 6.185um 1.155um
#
#  -6.185um 0.685um -5.955um 0.755um
#
#  -6.185um 0.685um -5.955um 0.755um
#
#  5.955um 0.685um 6.185um 0.755um
#
#  5.955um 0.685um 6.185um 0.755um
#
#  -6.185um 0.285um -5.955um 0.355um
#
#  -6.185um 0.285um -5.955um 0.355um
#
#  -6.185um -0.115um -5.955um -0.045um
#
#  -6.185um -0.115um -5.955um -0.045um
#
#  -6.185um -0.515um -5.955um -0.445um
#
#  -6.185um -0.515um -5.955um -0.445um
#
#  -6.185um -0.915um -5.955um -0.845um
#
#  -6.185um -0.915um -5.955um -0.845um
#
#  5.955um 0.285um 6.185um 0.355um
#
#  5.955um 0.285um 6.185um 0.355um
#
#  5.955um -0.115um 6.185um -0.045um
#
#  5.955um -0.115um 6.185um -0.045um
#
#  -6.185um -1.315um -5.955um -1.245um
#
#  -6.185um -1.315um -5.955um -1.245um
#
#  5.955um -0.515um 6.185um -0.445um
#
#  5.955um -0.515um 6.185um -0.445um
#
#  5.955um -0.915um 6.185um -0.845um
#
#  5.955um -0.915um 6.185um -0.845um
#
#  5.955um -1.315um 6.185um -1.245um
#
#  5.955um -1.315um 6.185um -1.245um
#
#  -6.185um -1.715um -5.955um -1.645um
#
#  -6.185um -1.715um -5.955um -1.645um
#
#  5.955um -1.715um 6.185um -1.645um
#
#  5.955um -1.715um 6.185um -1.645um
#
#  -4.915um -2.950um -4.785um -2.895um
#
#  -4.915um -2.950um -4.785um -2.895um
#
#  -4.785um -2.950um -4.685um -2.895um
#
#  -4.785um -2.950um -4.685um -2.895um
#
#  -4.115um -2.950um -3.885um -2.895um
#
#  -4.115um -2.950um -3.885um -2.895um
#
#  -2.515um -2.950um -2.285um -2.895um
#
#  -2.515um -2.950um -2.285um -2.895um
#
#  -0.915um -2.950um -0.785um -2.895um
#
#  -0.915um -2.950um -0.785um -2.895um
#
#  -0.115um -2.950um 0.115um -2.895um
#
#  -0.115um -2.950um 0.115um -2.895um
#
#  0.785um -2.950um 0.915um -2.895um
#
#  0.785um -2.950um 0.915um -2.895um
#
#  2.285um -2.950um 2.395um -2.895um
#
#  2.285um -2.950um 2.395um -2.895um
#
#  2.395um -2.950um 2.515um -2.895um
#
#  2.395um -2.950um 2.515um -2.895um
#
#  3.885um -2.950um 4.115um -2.895um
#
#  3.885um -2.950um 4.115um -2.895um
#
#  4.685um -2.950um 4.915um -2.895um
#
#  4.685um -2.950um 4.915um -2.895um
#
# ----------------------------------------
#
#
#
# DRC: {'result_str': 'magic drc script passed\nErrors found in DRC report', 'subproc_code': 0}
# using default pdk_root
# LVS skipped: No netlist found in component info for 'stacked_nfet_current_mirror'. Cannot run LVS.

# %%
try:
    from glayout.verification.evaluator_wrapper import run_evaluation
except ImportError:
    print("Warning: evaluator_wrapper not found. Evaluation will be skipped.")
    run_evaluation = None

if run_evaluation is not None:
    # Provide a representative netlist for LVS (stacked nfet current mirror topology)
    if 'netlist' not in comp.info or not comp.info.get('netlist'):
        _spice = """.subckt STACKED_CMIRROR VREF VOUT VSS B
MN0 VREF VREF VSS B nfet_03v3 w=0.5u l=0.28u m=1
MN1 VOUT VREF VSS B nfet_03v3 w=0.5u l=0.28u m=4
.ends STACKED_CMIRROR"""
        comp.info['netlist'] = _spice
    result = run_evaluation("stacked_nfet_current_mirror.gds", comp.name, comp)
    print(result)
# Out:
# /home/irman/Gelochip/src/gelochip/glayout/verification/verification.py:148: UserWarning: Unnamed cells, 2 in 'STACKED_NFET_CURRENT_MIRROR'
#   top_level.write_gds(new_gds)
# 2026-05-18 20:38:01.628 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/home/irman/Gelochip/notebooks/datasets/stacked_current_mirror/STACKED_NFET_CURRENT_MIRROR.gds'
# --- Starting Comprehensive Evaluation for stacked_nfet_current_mirror ---
# Cleaning up intermediate files for component 'stacked_nfet_current_mirror'...
#   - Deleted: stacked_nfet_current_mirror.nodes
#   - Deleted: stacked_nfet_current_mirror.sim
# Running verification checks (DRC, LVS)...
# using default pdk_root
# Defaulting to stale magic_commands.tcl
# /home/irman/Gelochip/src/gelochip/glayout/pdk/mappedpdk.py:762: UserWarning: Unnamed cells, 2 in 'STACKED_NFET_CURRENT_MIRROR'
#   layout.write_gds(str(gds_path))
# 2026-05-18 20:38:01.848 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR.gds'
# Magic 8.3 revision 644 - Compiled on Sun May 17 10:32:25 PM WIB 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpo2mssycw/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "STACKED_NFET_CURRENT_MIRROR".
# Reading "Unnamed_9aea5573".
# Reading "Unnamed_8e719756".
# [INFO]: Loading STACKED_NFET_CURRENT_MIRROR
#
# Loading DRC CIF style.
# [INFO]: DONE with /tmp/tmpo2mssycw/STACKED_NFET_CURRENT_MIRROR.rpt
#
# Using technology "gf180mcuD", version 1.0.493-0-g0fe599b
#
# STACKED_NFET_CURRENT_MIRROR count:
#
# ----------------------------------------
#
# Metal2 spacing < 0.28um (M2.2a)
#
# ----------------------------------------
#
#  -2.810um 2.350um 2.530um 2.475um
#
#  -2.810um 2.240um 2.530um 2.350um
#
#  -2.530um -0.105um 2.530um 0.130um
#
#  -3.630um -2.340um -3.520um -2.305um
#
#  -3.520um -2.340um -3.240um -2.305um
#
#  -3.240um -2.340um 2.530um -2.305um
#
#  -3.630um -2.450um 2.530um -2.340um
#
# ----------------------------------------
#
# This layer can't abut or partially overlap between subcells
#
# ----------------------------------------
#
#  -2.515um 2.720um -2.285um 2.950um
#
#  -2.285um 2.870um -2.270um 2.950um
#
#  -2.515um 2.720um -2.285um 2.950um
#
#  -2.530um 2.705um -2.150um 2.720um
#
#  -2.530um 2.870um -2.270um 2.965um
#
#  -2.530um 2.705um -2.150um 2.870um
#
#  -0.130um 2.720um -0.115um 2.950um
#
#  -0.115um 2.720um 0.115um 2.950um
#
#  0.115um 2.720um 0.130um 2.950um
#
#  -0.130um 2.610um 0.130um 2.965um
#
#  2.285um 2.720um 2.515um 2.950um
#
#  2.150um 2.705um 2.530um 2.720um
#
#  2.270um 2.870um 2.285um 2.950um
#
#  2.285um 2.720um 2.515um 2.950um
#
#  2.150um 2.705um 2.530um 2.870um
#
#  2.270um 2.870um 2.530um 2.965um
#
#  -1.270um 1.555um -1.010um 1.825um
#
#  -1.270um 1.310um -1.010um 1.825um
#
#  1.010um 1.555um 1.270um 1.825um
#
#  1.010um 1.310um 1.270um 1.825um
#
#  -1.270um -0.790um -1.010um -0.520um
#
#  -1.270um -1.035um -1.010um -0.520um
#
#  1.010um -0.790um 1.270um -0.520um
#
#  1.010um -1.035um 1.270um -0.520um
#
#  -1.850um -3.000um -1.570um -2.760um
#
#  -0.710um -3.000um -0.430um -2.760um
#
#  0.430um -3.000um 0.710um -2.760um
#
#  1.570um -3.000um 1.850um -2.760um
#
#  -2.285um 2.720um -2.150um 2.870um
#
#  -2.530um 2.705um -2.150um 2.720um
#
#  -2.530um 2.705um -2.150um 2.870um
#
#  -2.410um 2.610um -2.150um 2.705um
#
#  -2.285um 2.720um -2.150um 2.870um
#
#  -2.530um 2.705um -2.150um 2.720um
#
#  -2.410um 2.610um -2.150um 2.705um
#
#  -2.530um 2.705um -2.150um 2.870um
#
#  -0.130um 2.610um 0.130um 2.720um
#
#  -0.130um 2.610um 0.130um 2.965um
#
#  2.150um 2.720um 2.285um 2.870um
#
#  2.150um 2.705um 2.530um 2.720um
#
#  2.150um 2.705um 2.530um 2.870um
#
#  2.150um 2.610um 2.410um 2.705um
#
#  2.150um 2.720um 2.285um 2.870um
#
#  2.150um 2.705um 2.530um 2.720um
#
#  2.150um 2.610um 2.410um 2.705um
#
#  2.150um 2.705um 2.530um 2.870um
#
#  -1.270um 1.555um -1.010um 1.825um
#
#  -1.270um 1.310um -1.010um 1.825um
#
#  1.010um 1.555um 1.270um 1.825um
#
#  1.010um 1.310um 1.270um 1.825um
#
#  -1.270um -0.790um -1.010um -0.520um
#
#  -1.270um -1.035um -1.010um -0.520um
#
#  1.010um -0.790um 1.270um -0.520um
#
#  1.010um -1.035um 1.270um -0.520um
#
# ----------------------------------------
#
# Via1 width < 0.26um (V1.1)
#
# ----------------------------------------
#
#  -2.270um 2.870um -2.150um 2.965um
#
#  2.150um 2.870um 2.270um 2.965um
#
# ----------------------------------------
#
# Can't overlap those layers
#
# ----------------------------------------
#
#  -4.470um -3.000um -4.190um -2.760um
#
#  -1.850um -3.000um -1.570um -2.760um
#
#  -0.710um -3.000um -0.430um -2.760um
#
#  0.430um -3.000um 0.710um -2.760um
#
#  1.570um -3.000um 1.850um -2.760um
#
#  4.190um -3.000um 4.470um -2.760um
#
#  -5.200um -3.015um -3.460um -3.000um
#
#  -2.600um -3.015um 2.600um -3.000um
#
#  3.460um -3.015um 5.200um -3.000um
#
# ----------------------------------------
#
# Via1 spacing < 0.26um (V1.2a)
#
# ----------------------------------------
#
#  -6.200um 1.885um -6.185um 1.990um
#
#  -6.185um 1.885um -5.955um 1.990um
#
#  -5.955um 1.885um -5.940um 1.990um
#
#  -6.200um 1.870um -5.940um 1.885um
#
#  -6.200um 1.485um -6.185um 1.590um
#
#  -6.185um 1.485um -5.955um 1.590um
#
#  -5.955um 1.485um -5.940um 1.590um
#
#  -6.200um 1.470um -5.940um 1.485um
#
#  5.940um 1.885um 5.955um 1.990um
#
#  5.955um 1.885um 6.185um 1.990um
#
#  6.185um 1.885um 6.200um 1.990um
#
#  5.940um 1.870um 6.200um 1.885um
#
#  -6.200um 1.085um -6.185um 1.190um
#
#  -6.185um 1.085um -5.955um 1.190um
#
#  -5.955um 1.085um -5.940um 1.190um
#
#  -6.200um 1.070um -5.940um 1.085um
#
#  5.940um 1.485um 5.955um 1.590um
#
#  5.955um 1.485um 6.185um 1.590um
#
#  6.185um 1.485um 6.200um 1.590um
#
#  5.940um 1.470um 6.200um 1.485um
#
#  5.940um 1.085um 5.955um 1.190um
#
#  5.955um 1.085um 6.185um 1.190um
#
#  6.185um 1.085um 6.200um 1.190um
#
#  5.940um 1.070um 6.200um 1.085um
#
#  -6.200um 0.685um -6.185um 0.790um
#
#  -6.185um 0.685um -5.955um 0.790um
#
#  -5.955um 0.685um -5.940um 0.790um
#
#  -6.200um 0.670um -5.940um 0.685um
#
#  -6.200um 0.285um -6.185um 0.390um
#
#  -6.185um 0.285um -5.955um 0.390um
#
#  -5.955um 0.285um -5.940um 0.390um
#
#  -6.200um 0.270um -5.940um 0.285um
#
#  -0.390um 0.525um -0.270um 0.530um
#
#  -0.130um 0.270um -0.010um 0.285um
#
#  -0.130um 0.285um -0.010um 0.515um
#
#  -0.130um 0.515um -0.010um 0.525um
#
#  0.270um 0.515um 0.390um 0.530um
#
#  0.270um 0.285um 0.285um 0.515um
#
#  0.285um 0.285um 0.390um 0.515um
#
#  0.270um 0.270um 0.390um 0.285um
#
#  5.940um 0.685um 5.955um 0.790um
#
#  5.955um 0.685um 6.185um 0.790um
#
#  6.185um 0.685um 6.200um 0.790um
#
#  5.940um 0.670um 6.200um 0.685um
#
#  -6.200um -0.115um -6.185um -0.010um
#
#  -6.185um -0.115um -5.955um -0.010um
#
#  -5.955um -0.115um -5.940um -0.010um
#
#  -6.200um -0.130um -5.940um -0.115um
#
#  -6.200um -0.515um -6.185um -0.410um
#
#  -6.185um -0.515um -5.955um -0.410um
#
#  -5.955um -0.515um -5.940um -0.410um
#
#  -6.200um -0.530um -5.940um -0.515um
#
#  -6.200um -0.915um -6.185um -0.810um
#
#  -6.185um -0.915um -5.955um -0.810um
#
#  -5.955um -0.915um -5.940um -0.810um
#
#  -6.200um -0.930um -5.940um -0.915um
#
#  5.940um 0.285um 5.955um 0.390um
#
#  5.955um 0.285um 6.185um 0.390um
#
#  6.185um 0.285um 6.200um 0.390um
#
#  5.940um 0.270um 6.200um 0.285um
#
#  5.940um -0.115um 5.955um -0.010um
#
#  5.955um -0.115um 6.185um -0.010um
#
#  6.185um -0.115um 6.200um -0.010um
#
#  5.940um -0.130um 6.200um -0.115um
#
#  -6.200um -1.315um -6.185um -1.210um
#
#  -6.185um -1.315um -5.955um -1.210um
#
#  -5.955um -1.315um -5.940um -1.210um
#
#  -6.200um -1.330um -5.940um -1.315um
#
#  5.940um -0.515um 5.955um -0.410um
#
#  5.955um -0.515um 6.185um -0.410um
#
#  6.185um -0.515um 6.200um -0.410um
#
#  5.940um -0.530um 6.200um -0.515um
#
#  5.940um -0.915um 5.955um -0.810um
#
#  5.955um -0.915um 6.185um -0.810um
#
#  6.185um -0.915um 6.200um -0.810um
#
#  5.940um -0.930um 6.200um -0.915um
#
#  5.940um -1.315um 5.955um -1.210um
#
#  5.955um -1.315um 6.185um -1.210um
#
#  6.185um -1.315um 6.200um -1.210um
#
#  5.940um -1.330um 6.200um -1.315um
#
#  -6.200um -1.715um -6.185um -1.610um
#
#  -6.185um -1.715um -5.955um -1.610um
#
#  -5.955um -1.715um -5.940um -1.610um
#
#  -6.200um -1.730um -5.940um -1.715um
#
#  -0.390um -1.820um -0.270um -1.815um
#
#  -0.130um -2.075um -0.010um -2.060um
#
#  -0.130um -2.060um -0.010um -1.830um
#
#  -0.130um -1.830um -0.010um -1.820um
#
#  0.270um -1.830um 0.390um -1.815um
#
#  0.270um -2.060um 0.285um -1.830um
#
#  0.285um -2.060um 0.390um -1.830um
#
#  0.270um -2.075um 0.390um -2.060um
#
#  5.940um -1.715um 5.955um -1.610um
#
#  5.955um -1.715um 6.185um -1.610um
#
#  6.185um -1.715um 6.200um -1.610um
#
#  5.940um -1.730um 6.200um -1.715um
#
#  -2.530um -2.950um -2.515um -2.860um
#
#  -2.515um -2.950um -2.285um -2.860um
#
#  -2.285um -2.950um -2.270um -2.860um
#
#  -2.530um -2.965um -2.270um -2.950um
#
#  -1.530um -2.965um -1.470um -2.950um
#
#  -0.930um -2.950um -0.915um -2.860um
#
#  -0.915um -2.950um -0.750um -2.860um
#
#  -0.930um -2.965um -0.750um -2.950um
#
#  -0.130um -2.950um -0.115um -2.860um
#
#  -0.115um -2.950um 0.115um -2.860um
#
#  0.115um -2.950um 0.130um -2.860um
#
#  -0.130um -2.965um 0.130um -2.950um
#
#  0.750um -2.950um 0.915um -2.860um
#
#  0.915um -2.950um 0.930um -2.860um
#
#  0.750um -2.965um 0.930um -2.950um
#
#  1.470um -2.965um 1.530um -2.950um
#
#  2.270um -2.950um 2.285um -2.860um
#
#  2.285um -2.950um 2.410um -2.860um
#
#  2.270um -2.965um 2.410um -2.950um
#
#  2.410um -2.950um 2.515um -2.860um
#
#  2.515um -2.950um 2.530um -2.860um
#
#  2.410um -2.965um 2.530um -2.950um
#
#  -6.200um 1.885um -6.185um 1.990um
#
#  -6.185um 1.885um -5.955um 1.990um
#
#  -5.955um 1.885um -5.940um 1.990um
#
#  -6.200um 1.870um -5.940um 1.885um
#
#  -6.200um 1.485um -6.185um 1.590um
#
#  -6.185um 1.485um -5.955um 1.590um
#
#  -5.955um 1.485um -5.940um 1.590um
#
#  -6.200um 1.470um -5.940um 1.485um
#
#  5.940um 1.885um 5.955um 1.990um
#
#  5.955um 1.885um 6.185um 1.990um
#
#  6.185um 1.885um 6.200um 1.990um
#
#  5.940um 1.870um 6.200um 1.885um
#
#  5.940um 1.485um 5.955um 1.590um
#
#  5.955um 1.485um 6.185um 1.590um
#
#  6.185um 1.485um 6.200um 1.590um
#
#  5.940um 1.470um 6.200um 1.485um
#
#  -6.200um 1.085um -6.185um 1.190um
#
#  -6.185um 1.085um -5.955um 1.190um
#
#  -5.955um 1.085um -5.940um 1.190um
#
#  -6.200um 1.070um -5.940um 1.085um
#
#  5.940um 1.085um 5.955um 1.190um
#
#  5.955um 1.085um 6.185um 1.190um
#
#  6.185um 1.085um 6.200um 1.190um
#
#  5.940um 1.070um 6.200um 1.085um
#
#  -6.200um 0.685um -6.185um 0.790um
#
#  -6.185um 0.685um -5.955um 0.790um
#
#  -5.955um 0.685um -5.940um 0.790um
#
#  -6.200um 0.670um -5.940um 0.685um
#
#  -6.200um 0.285um -6.185um 0.390um
#
#  -6.185um 0.285um -5.955um 0.390um
#
#  -5.955um 0.285um -5.940um 0.390um
#
#  -6.200um 0.270um -5.940um 0.285um
#
#  -0.390um 0.525um -0.270um 0.530um
#
#  -0.130um 0.270um -0.010um 0.525um
#
#  0.270um 0.515um 0.390um 0.530um
#
#  0.270um 0.285um 0.285um 0.515um
#
#  0.285um 0.285um 0.390um 0.515um
#
#  0.270um 0.270um 0.390um 0.285um
#
#  5.940um 0.685um 5.955um 0.790um
#
#  5.955um 0.685um 6.185um 0.790um
#
#  6.185um 0.685um 6.200um 0.790um
#
#  5.940um 0.670um 6.200um 0.685um
#
#  5.940um 0.285um 5.955um 0.390um
#
#  5.955um 0.285um 6.185um 0.390um
#
#  6.185um 0.285um 6.200um 0.390um
#
#  5.940um 0.270um 6.200um 0.285um
#
#  -6.200um -0.115um -6.185um -0.010um
#
#  -6.185um -0.115um -5.955um -0.010um
#
#  -5.955um -0.115um -5.940um -0.010um
#
#  -6.200um -0.130um -5.940um -0.115um
#
#  -6.200um -0.515um -6.185um -0.410um
#
#  -6.185um -0.515um -5.955um -0.410um
#
#  -5.955um -0.515um -5.940um -0.410um
#
#  -6.200um -0.530um -5.940um -0.515um
#
#  -6.200um -0.915um -6.185um -0.810um
#
#  -6.185um -0.915um -5.955um -0.810um
#
#  -5.955um -0.915um -5.940um -0.810um
#
#  -6.200um -0.930um -5.940um -0.915um
#
#  5.940um -0.115um 5.955um -0.010um
#
#  5.955um -0.115um 6.185um -0.010um
#
#  6.185um -0.115um 6.200um -0.010um
#
#  5.940um -0.130um 6.200um -0.115um
#
#  5.940um -0.515um 5.955um -0.410um
#
#  5.955um -0.515um 6.185um -0.410um
#
#  6.185um -0.515um 6.200um -0.410um
#
#  5.940um -0.530um 6.200um -0.515um
#
#  5.940um -0.915um 5.955um -0.810um
#
#  5.955um -0.915um 6.185um -0.810um
#
#  6.185um -0.915um 6.200um -0.810um
#
#  5.940um -0.930um 6.200um -0.915um
#
#  -6.200um -1.315um -6.185um -1.210um
#
#  -6.185um -1.315um -5.955um -1.210um
#
#  -5.955um -1.315um -5.940um -1.210um
#
#  -6.200um -1.330um -5.940um -1.315um
#
#  -6.200um -1.715um -6.185um -1.610um
#
#  -6.185um -1.715um -5.955um -1.610um
#
#  -5.955um -1.715um -5.940um -1.610um
#
#  -6.200um -1.730um -5.940um -1.715um
#
#  -0.390um -1.820um -0.270um -1.815um
#
#  -0.130um -2.075um -0.010um -1.820um
#
#  0.270um -1.830um 0.390um -1.815um
#
#  0.270um -2.060um 0.285um -1.830um
#
#  0.285um -2.060um 0.390um -1.830um
#
#  0.270um -2.075um 0.390um -2.060um
#
#  5.940um -1.315um 5.955um -1.210um
#
#  5.955um -1.315um 6.185um -1.210um
#
#  6.185um -1.315um 6.200um -1.210um
#
#  5.940um -1.330um 6.200um -1.315um
#
#  5.940um -1.715um 5.955um -1.610um
#
#  5.955um -1.715um 6.185um -1.610um
#
#  6.185um -1.715um 6.200um -1.610um
#
#  5.940um -1.730um 6.200um -1.715um
#
#  -2.530um -2.950um -2.515um -2.860um
#
#  -2.515um -2.950um -2.285um -2.860um
#
#  -2.285um -2.950um -2.270um -2.860um
#
#  -2.530um -2.965um -2.270um -2.950um
#
#  -1.530um -2.965um -1.470um -2.950um
#
#  -0.930um -2.950um -0.915um -2.860um
#
#  -0.915um -2.950um -0.750um -2.860um
#
#  -0.930um -2.965um -0.750um -2.950um
#
#  -0.130um -2.950um -0.115um -2.860um
#
#  -0.115um -2.950um 0.115um -2.860um
#
#  0.115um -2.950um 0.130um -2.860um
#
#  -0.130um -2.965um 0.130um -2.950um
#
#  0.750um -2.950um 0.915um -2.860um
#
#  0.915um -2.950um 0.930um -2.860um
#
#  0.750um -2.965um 0.930um -2.950um
#
#  1.470um -2.965um 1.530um -2.950um
#
#  2.270um -2.950um 2.285um -2.860um
#
#  2.285um -2.950um 2.410um -2.860um
#
#  2.270um -2.965um 2.410um -2.950um
#
#  2.410um -2.950um 2.515um -2.860um
#
#  2.515um -2.950um 2.530um -2.860um
#
#  2.410um -2.965um 2.530um -2.950um
#
# ----------------------------------------
#
# Diffusion contact spacing < 0.24um (CO.2a - 2 * CO.6)
#
# ----------------------------------------
#
#  -6.185um 1.885um -5.955um 1.955um
#
#  5.955um 1.885um 6.185um 1.955um
#
#  -6.185um 1.485um -5.955um 1.555um
#
#  5.955um 1.485um 6.185um 1.555um
#
#  -6.185um 1.085um -5.955um 1.155um
#
#  -6.185um 0.685um -5.955um 0.755um
#
#  -6.185um 0.285um -5.955um 0.355um
#
#  5.955um 1.085um 6.185um 1.155um
#
#  5.955um 0.685um 6.185um 0.755um
#
#  -6.185um -0.115um -5.955um -0.045um
#
#  5.955um 0.285um 6.185um 0.355um
#
#  5.955um -0.115um 6.185um -0.045um
#
#  -6.185um -0.515um -5.955um -0.445um
#
#  -6.185um -0.915um -5.955um -0.845um
#
#  5.955um -0.515um 6.185um -0.445um
#
#  5.955um -0.915um 6.185um -0.845um
#
#  -6.185um -1.315um -5.955um -1.245um
#
#  -6.185um -1.715um -5.955um -1.645um
#
#  5.955um -1.315um 6.185um -1.245um
#
#  5.955um -1.715um 6.185um -1.645um
#
#  -4.915um -2.950um -4.785um -2.895um
#
#  -4.785um -2.950um -4.685um -2.895um
#
#  -4.115um -2.950um -3.885um -2.895um
#
#  -2.515um -2.950um -2.285um -2.895um
#
#  -0.915um -2.950um -0.785um -2.895um
#
#  -0.115um -2.950um 0.115um -2.895um
#
#  0.785um -2.950um 0.915um -2.895um
#
#  2.285um -2.950um 2.395um -2.895um
#
#  2.395um -2.950um 2.515um -2.895um
#
#  3.885um -2.950um 4.115um -2.895um
#
#  4.685um -2.950um 4.915um -2.895um
#
#  -6.185um 1.885um -5.955um 1.955um
#
#  -6.185um 1.885um -5.955um 1.955um
#
#  -6.185um 1.485um -5.955um 1.555um
#
#  -6.185um 1.485um -5.955um 1.555um
#
#  -6.185um 1.085um -5.955um 1.155um
#
#  -6.185um 1.085um -5.955um 1.155um
#
#  5.955um 1.885um 6.185um 1.955um
#
#  5.955um 1.885um 6.185um 1.955um
#
#  5.955um 1.485um 6.185um 1.555um
#
#  5.955um 1.485um 6.185um 1.555um
#
#  5.955um 1.085um 6.185um 1.155um
#
#  5.955um 1.085um 6.185um 1.155um
#
#  -6.185um 0.685um -5.955um 0.755um
#
#  -6.185um 0.685um -5.955um 0.755um
#
#  5.955um 0.685um 6.185um 0.755um
#
#  5.955um 0.685um 6.185um 0.755um
#
#  -6.185um 0.285um -5.955um 0.355um
#
#  -6.185um 0.285um -5.955um 0.355um
#
#  -6.185um -0.115um -5.955um -0.045um
#
#  -6.185um -0.115um -5.955um -0.045um
#
#  -6.185um -0.515um -5.955um -0.445um
#
#  -6.185um -0.515um -5.955um -0.445um
#
#  -6.185um -0.915um -5.955um -0.845um
#
#  -6.185um -0.915um -5.955um -0.845um
#
#  5.955um 0.285um 6.185um 0.355um
#
#  5.955um 0.285um 6.185um 0.355um
#
#  5.955um -0.115um 6.185um -0.045um
#
#  5.955um -0.115um 6.185um -0.045um
#
#  -6.185um -1.315um -5.955um -1.245um
#
#  -6.185um -1.315um -5.955um -1.245um
#
#  5.955um -0.515um 6.185um -0.445um
#
#  5.955um -0.515um 6.185um -0.445um
#
#  5.955um -0.915um 6.185um -0.845um
#
#  5.955um -0.915um 6.185um -0.845um
#
#  5.955um -1.315um 6.185um -1.245um
#
#  5.955um -1.315um 6.185um -1.245um
#
#  -6.185um -1.715um -5.955um -1.645um
#
#  -6.185um -1.715um -5.955um -1.645um
#
#  5.955um -1.715um 6.185um -1.645um
#
#  5.955um -1.715um 6.185um -1.645um
#
#  -4.915um -2.950um -4.785um -2.895um
#
#  -4.915um -2.950um -4.785um -2.895um
#
#  -4.785um -2.950um -4.685um -2.895um
#
#  -4.785um -2.950um -4.685um -2.895um
#
#  -4.115um -2.950um -3.885um -2.895um
#
#  -4.115um -2.950um -3.885um -2.895um
#
#  -2.515um -2.950um -2.285um -2.895um
#
#  -2.515um -2.950um -2.285um -2.895um
#
#  -0.915um -2.950um -0.785um -2.895um
#
#  -0.915um -2.950um -0.785um -2.895um
#
#  -0.115um -2.950um 0.115um -2.895um
#
#  -0.115um -2.950um 0.115um -2.895um
#
#  0.785um -2.950um 0.915um -2.895um
#
#  0.785um -2.950um 0.915um -2.895um
#
#  2.285um -2.950um 2.395um -2.895um
#
#  2.285um -2.950um 2.395um -2.895um
#
#  2.395um -2.950um 2.515um -2.895um
#
#  2.395um -2.950um 2.515um -2.895um
#
#  3.885um -2.950um 4.115um -2.895um
#
#  3.885um -2.950um 4.115um -2.895um
#
#  4.685um -2.950um 4.915um -2.895um
#
#  4.685um -2.950um 4.915um -2.895um
#
# ----------------------------------------
#
#
#
# using default pdk_root
# Magic 8.3 revision 644 - Compiled on Sun May 17 10:32:25 PM WIB 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.493-0-g0fe599b
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "STACKED_NFET_CURRENT_MIRROR".
# Reading "Unnamed_9aea5573".
# Reading "Unnamed_8e719756".
# Extracting Unnamed_8e719756 into Unnamed_8e719756.ext:
# Processing Unnamed_8e719756
# Unnamed_8e719756: 24 warnings
# Extracting Unnamed_9aea5573 into Unnamed_9aea5573.ext:
# Processing Unnamed_9aea5573
# Unnamed_9aea5573: 2 warnings
# Extracting STACKED_NFET_CURRENT_MIRROR into STACKED_NFET_CURRENT_MIRROR.ext:
# Processing STACKED_NFET_CURRENT_MIRROR
# STACKED_NFET_CURRENT_MIRROR: 186 errors
# exttospice finished.
# Extracting Unnamed_8e719756 into Unnamed_8e719756.ext:
# Processing Unnamed_8e719756
# Unnamed_8e719756: 24 warnings
# Extracting Unnamed_9aea5573 into Unnamed_9aea5573.ext:
# Processing Unnamed_9aea5573
# Unnamed_9aea5573: 2 warnings
# Extracting STACKED_NFET_CURRENT_MIRROR into STACKED_NFET_CURRENT_MIRROR.ext:
# Processing STACKED_NFET_CURRENT_MIRROR
# STACKED_NFET_CURRENT_MIRROR: 186 errors
# exttosim finished.
# Extracting Unnamed_8e719756 into Unnamed_8e719756.ext:
# Processing Unnamed_8e719756
# Unnamed_8e719756: 24 warnings
# Extracting Unnamed_9aea5573 into Unnamed_9aea5573.ext:
# Processing Unnamed_9aea5573
# Unnamed_9aea5573: 2 warnings
# Extracting STACKED_NFET_CURRENT_MIRROR into STACKED_NFET_CURRENT_MIRROR.ext:
# Processing STACKED_NFET_CURRENT_MIRROR
# STACKED_NFET_CURRENT_MIRROR: 186 errors
# exttosim finished.
# Total Nets: 4
# Nets extracted: 0 (0.000000)
# Nets output: 0 (0.000000)
# exttospice finished.
#
# Running netgen command: netgen -batch lvs "/tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR_lvsmag.spice STACKED_NFET_CURRENT_MIRROR" "/tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR.spice STACKED_NFET_CURRENT_MIRROR" /home/irman/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR_lvs.rpt
# Netgen 1.5.272 compiled on Mon May 18 06:54:31 AM WIB 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR_lvsmag.spice
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR.spice
# Call to undefined subcircuit pmos_3p3
# Creating placeholder cell definition.
# Call to undefined subcircuit nmos_3p3
# Creating placeholder cell definition.
#
# Reading setup file /home/irman/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property area found for device c
# No property as found for device nfet_03v3
# No property ad found for device nfet_03v3
# No property ps found for device nfet_03v3
# No property pd found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No such pin 1 in model nfet_03v3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property as found for device nfet_03v3
# No property ad found for device nfet_03v3
# No property ps found for device nfet_03v3
# No property pd found for device nfet_03v3
# Comparison output logged to file /tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR_lvs.rpt
# Logging to file "/tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR_lvs.rpt" enabled
#
# Contents of circuit 1:  Circuit: 'nfet_03v3'
# Circuit nfet_03v3 contains 0 device instances.
# Circuit contains 0 nets.
# Contents of circuit 2:  Circuit: 'nfet_03v3'
# Circuit nfet_03v3 contains 0 device instances.
# Circuit contains 0 nets, and 4 disconnected pins.
#
# Circuit nfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'STACKED_NFET_CURRENT_MIRROR'
# Circuit STACKED_NFET_CURRENT_MIRROR contains 30 device instances.
#   Class: nfet_03v3             instances:  30
# Circuit contains 122 nets.
# Contents of circuit 2:  Circuit: 'STACKED_NFET_CURRENT_MIRROR'
# Circuit STACKED_NFET_CURRENT_MIRROR contains 2 device instances.
#   Class: nfet_03v3             instances:   2
# Circuit contains 12 nets.
#
# Circuit was modified by parallel/series device merging.
# New circuit summary:
#
# Contents of circuit 1:  Circuit: 'STACKED_NFET_CURRENT_MIRROR'
# Circuit STACKED_NFET_CURRENT_MIRROR contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 122 nets.
# Contents of circuit 2:  Circuit: 'STACKED_NFET_CURRENT_MIRROR'
# Circuit STACKED_NFET_CURRENT_MIRROR contains 2 device instances.
#   Class: nfet_03v3             instances:   2
# Circuit contains 12 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 2 devices. *** MISMATCH ***
# Circuit 1 contains 5 nets,    Circuit 2 contains 12 nets. *** MISMATCH ***
#
#
# Final result:
# Top level cell failed pin matching.
#
# Logging to file "/tmp/tmpowyoc4of/STACKED_NFET_CURRENT_MIRROR_lvs.rpt" disabled
# LVS Done.
#
#
# Cell nfet_03v3 (1) disconnected node: drain
# Cell nfet_03v3 (1) disconnected node: gate
# Cell nfet_03v3 (1) disconnected node: source
# Cell nfet_03v3 (1) disconnected node: bulk
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# (no matching pin)                          |drain
# (no matching pin)                          |gate
# (no matching pin)                          |source
# (no matching pin)                          |bulk
# 1                                          |(no matching pin)
# 2                                          |(no matching pin)
# 3                                          |(no matching pin)
# 4                                          |(no matching pin)
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
# Flattening unmatched subcell Unnamed_8e719756 in circuit STACKED_NFET_CURRENT_MIRROR (0)(1 instance)
# Flattening unmatched subcell Unnamed_9aea5573 in circuit STACKED_NFET_CURRENT_MIRROR (0)(1 instance)
#
# Class STACKED_NFET_CURRENT_MIRROR (0):  Merged 29 parallel devices.
# Subcircuit summary:
# Circuit 1: STACKED_NFET_CURRENT_MIRROR     |Circuit 2: STACKED_NFET_CURRENT_MIRROR
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (30->1)                          |nfet_03v3 (5->2) **Mismatch**
# Number of devices: 1 **Mismatch**          |Number of devices: 2 **Mismatch**
# Number of nets: 5 **Mismatch**             |Number of nets: 12 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: STACKED_NFET_CURRENT_MIRROR     |Circuit 2: STACKED_NFET_CURRENT_MIRROR
#
# ---------------------------------------------------------------------------------------
# Net: VSUBS                                 |Net: VOUT
#   nfet_03v3/(1|3) = 2                      |  nfet_03v3/(drain|source) = 1
#   nfet_03v3/2 = 1                          |
#   nfet_03v3/4 = 1                          |
#                                            |
# Net: /Unnamed_8e719756_0/dummy_4           |Net: VREF
#   nfet_03v3/proxydrain = 1                 |  nfet_03v3/(drain|source) = 1
#                                            |  nfet_03v3/gate = 2
#                                            |
# Net: /Unnamed_8e719756_0/dummy_5           |(no matching net)
#   nfet_03v3/proxygate = 1                  |
#                                            |
# Net: /Unnamed_8e719756_0/dummy_6           |(no matching net)
#   nfet_03v3/proxysource = 1                |
#                                            |
# Net: /Unnamed_8e719756_0/dummy_7           |(no matching net)
#   nfet_03v3/proxybulk = 1                  |
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# (no matching net)                          |Net: B
#                                            |  nfet_03v3/bulk = 2
#                                            |
# (no matching net)                          |Net: VSS
#                                            |  nfet_03v3/(drain|source) = 2
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: STACKED_NFET_CURRENT_MIRROR     |Circuit 2: STACKED_NFET_CURRENT_MIRROR
#
# ---------------------------------------------------------------------------------------
# Instance: Unnamed_8e719756_0/nfet_03v3:0   |(no matching instance)
#   (1,3) = (4,4)                            |
#   2 = 4                                    |
#   4 = 4                                    |
#   proxydrain = 1                           |
#   proxygate = 1                            |
#   proxysource = 1                          |
#   proxybulk = 1                            |
#                                            |
# ---------------------------------------------------------------------------------------
# Netlists do not match.
#
# Subcircuit pins:
# Circuit 1: STACKED_NFET_CURRENT_MIRROR     |Circuit 2: STACKED_NFET_CURRENT_MIRROR
# -------------------------------------------|-------------------------------------------
# (no matching pin)                          |VREF
# (no matching pin)                          |VOUT
# (no matching pin)                          |VSS
# (no matching pin)                          |B
# proxyB                                     |(no matching pin)
# ---------------------------------------------------------------------------------------
# Cell pin lists for STACKED_NFET_CURRENT_MIRROR and STACKED_NFET_CURRENT_MIRROR altered to match.
# Device classes STACKED_NFET_CURRENT_MIRROR and STACKED_NFET_CURRENT_MIRROR are equivalent.
#
# Final result: Top level cell failed pin matching.
#
# Running physical feature extraction (PEX, Area, Symmetry)...
# --- Evaluation complete. Results saved to stacked_nfet_current_mirror_3.json ---
# {'component_name': 'stacked_nfet_current_mirror', 'timestamp': '2026-05-18T20:38:02.481463', 'drc_lvs_fail': True, 'drc': {'status': 'fail', 'is_pass': False, 'report_path': '/home/irman/Gelochip/notebooks/datasets/stacked_current_mirror/STACKED_NFET_CURRENT_MIRROR_drc_out/drc/STACKED_NFET_CURRENT_MIRROR/STACKED_NFET_CURRENT_MIRROR.rpt', 'summary': {'is_pass': False, 'total_errors': 193, 'error_details': [{'rule': "This layer can't abut or partially overlap between subcells", 'details': '0.115um 2.720um 0.130um 2.950um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.285um 2.720um 2.515um 2.950um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.705um 2.530um 2.720um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.270um 2.870um 2.285um 2.950um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.285um 2.720um 2.515um 2.950um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.705um 2.530um 2.870um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.270um 2.870um 2.530um 2.965um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um 1.555um 1.270um 1.825um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um 1.310um 1.270um 1.825um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um -0.790um 1.270um -0.520um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um -1.035um 1.270um -0.520um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '0.430um -3.000um 0.710um -2.760um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.570um -3.000um 1.850um -2.760um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.720um 2.285um 2.870um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.705um 2.530um 2.720um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.705um 2.530um 2.870um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.610um 2.410um 2.705um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.720um 2.285um 2.870um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.705um 2.530um 2.720um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.610um 2.410um 2.705um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '2.150um 2.705um 2.530um 2.870um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um 1.555um 1.270um 1.825um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um 1.310um 1.270um 1.825um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um -0.790um 1.270um -0.520um'}, {'rule': "This layer can't abut or partially overlap between subcells", 'details': '1.010um -1.035um 1.270um -0.520um'}, {'rule': 'Via1 width < 0.26um (V1.1)', 'details': '2.150um 2.870um 2.270um 2.965um'}, {'rule': "Can't overlap those layers", 'details': '0.430um -3.000um 0.710um -2.760um'}, {'rule': "Can't overlap those layers", 'details': '1.570um -3.000um 1.850um -2.760um'}, {'rule': "Can't overlap those layers", 'details': '4.190um -3.000um 4.470um -2.760um'}, {'rule': "Can't overlap those layers", 'details': '3.460um -3.015um 5.200um -3.000um'}, {'rule': 'Via1 spacing < 0.26um (V1.2a)', 'details': '5.940um 1.885um 5.955um 1.990um'}, {'rule': 'Via1 spacing < 0.26um (V1.2a)', 'details': '5.955um 1.885um 6.185um ...

# %%
# ── SPICE Simulation with gf180 PDK models ─────────────────────────────────
import subprocess, os, re, tempfile

_GF180_MODELS = '/home/irman/Gelochip/src/gelochip/glayout/spice/gf180_typical.spice'

class _StringNetlist:
    def __init__(self, spice_str):
        import re as _re
        self._spice = spice_str
        # Use the LAST .subckt definition (top-level circuit)
        matches = list(_re.finditer(r'\.subckt\s+(\w+)\s+(.*)', spice_str, _re.IGNORECASE))
        if matches:
            m = matches[-1]
            self.circuit_name = m.group(1)
            # Filter out parameter-style tokens (containing =)
            self.nodes = [n for n in m.group(2).split() if '=' not in n]
        else:
            self.circuit_name = 'UNKNOWN'; self.nodes = []
    def generate_netlist(self): return self._spice

def _get_netlist(comp):
    if not hasattr(comp, 'info'): return None
    nl = comp.info.get('netlist_obj')
    if nl is not None and hasattr(nl, 'generate_netlist'): return nl
    nl = comp.info.get('netlist')
    if nl is not None and hasattr(nl, 'generate_netlist'): return nl
    if isinstance(nl, str) and nl.strip(): return _StringNetlist(nl)
    return None

def _fix_spice(spice):
    spice = re.sub(r'm=\{(\d+)\}', lambda x: f'm={x.group(1)}', spice)
    # Resolve l={expr}/w={expr} parameter placeholders to defaults
    spice = re.sub(r'\bl=\{[^}]+\}', 'l=0.28', spice)
    spice = re.sub(r'\bw=\{[^}]+\}', 'w=0.28', spice)
    # Clamp l/w to gf180 minimum valid values (in µm) to stay within model bins
    def _clamp_l(m):
        try: v = float(m.group(1)); return f'l={max(v, 0.28)}'
        except: return m.group(0)
    def _clamp_w(m):
        try: v = float(m.group(1)); return f'w={max(v, 0.22)}'
        except: return m.group(0)
    spice = re.sub(r'\bl=([\d.]+)', _clamp_l, spice)
    spice = re.sub(r'\bw=([\d.]+)', _clamp_w, spice)
    # Remove mimcap lines (not in gf180 model file)
    spice = re.sub(r'^.*mimcap.*$', '* mimcap removed', spice, flags=re.MULTILINE | re.IGNORECASE)
    return spice

def _build_testbench(name, nodes, vdd=3.3):
    nmap = {}
    for n in nodes:
        u = n.upper()
        if u in ('VDD', 'AVDD', 'VCC'): nmap[n] = 'vdd'
        elif u in ('VSS', 'GND', 'AVSS'): nmap[n] = '0'
        elif u in ('VB', 'VBULK', 'BULK', 'B'): nmap[n] = '0'
        else: nmap[n] = f'n_{n.lower()}'
    lines = [f'VDD vdd 0 DC {vdd}V']
    for n in nodes:
        u, c = n.upper(), nmap[n]
        if c in ('vdd', '0'): continue
        if any(k in u for k in ('INP', 'VINP', 'VP')):
            lines.append(f'V_{n} {c} 0 DC {vdd*0.55:.3f}')
        elif any(k in u for k in ('INM', 'VINM', 'VN')):
            lines.append(f'V_{n} {c} 0 DC {vdd*0.45:.3f}')
        elif any(k in u for k in ('IBIAS','NBC_','NB_10U','NB_','BIAS','DIFFPAIR_BIAS','CS_BIAS')):
            lines.append(f'I_{n} vdd {c} DC 10u')
        elif u == 'VREF':
            lines.append(f'Iref_{n} vdd {c} DC 10u')
        elif u in ('VOUT','OUTPUT','OUT','CSOUTPUT') or u.startswith('VOUT'):
            lines.append(f'RL_{n} vdd {c} 100k')
        elif u == 'VIN':
            lines.append(f'V_{n} {c} 0 DC {vdd*0.5:.3f}')
        elif u == 'VGN':
            lines.append(f'V_{n} {c} 0 DC {vdd:.3f}')
        elif u == 'VGP':
            lines.append(f'V_{n} {c} 0 DC 0')
        else:
            lines.append(f'V_{n} {c} 0 DC {vdd*0.5:.3f}')
    inst = ' '.join(nmap[n] for n in nodes)
    lines += [f'XDUT {inst} {name}', '.op',
              '.options GMIN=1e-12 RELTOL=1e-3 ITL1=500', '.save all']
    return '\n'.join(lines)

def run_spice_gf180(comp, label=''):
    nl = _get_netlist(comp)
    if nl is None:
        print(f'No netlist in {label or "component"}.info')
        return
    spice = _fix_spice(nl.generate_netlist())
    name = nl.circuit_name
    nodes = list(nl.nodes)
    print(f'Circuit : {name}')
    print(f'Nodes   : {nodes}')
    tb = _build_testbench(name, nodes)
    full = f'* {label or name}\n.include "{_GF180_MODELS}"\n\n{spice}\n\n{tb}\n.end\n'
    with tempfile.NamedTemporaryFile(mode='w', suffix='.sp', delete=False, dir='/tmp') as f:
        f.write(full); sp = f.name
    out_f = sp + '.out'
    try:
        r = subprocess.run(['ngspice', '-b', '-o', out_f, sp],
                           capture_output=True, text=True, timeout=60)
        raw = open(out_f).read() if os.path.exists(out_f) else r.stdout + r.stderr
        print(f'\n── DC Operating Point: {label or name} ──')
        in_tbl = False
        for line in raw.split('\n'):
            l = line.strip()
            if re.match(r'node\b.*voltage', l, re.I): in_tbl = True; print(f'\n{line}')
            elif in_tbl and re.match(r'-{3,}', l): print(line)
            elif in_tbl and not l: in_tbl = False
            elif in_tbl: print(line)
        no_conv = 'no convergence' in raw.lower()
        if r.returncode == 0 and not no_conv:
            print('\n\u2713 Converged \u2013 gf180 typical corner')
        elif no_conv:
            print('\n\u26a0 No convergence')
        else:
            errs = [l for l in raw.split('\n') if 'error' in l.lower() and l.strip()]
            print(f'\n\u26a0 ngspice exit {r.returncode}')
            for e in errs[:3]: print(f'  {e}')
    except Exception as e:
        print(f'Simulation error: {e}')
    finally:
        for fn in [sp, out_f]:
            try: os.unlink(fn)
            except: pass

run_spice_gf180(cm, label='stacked_nfet_cmirror')
# Out:
# Circuit : STACKED_CMIRROR
# Nodes   : ['VREF', 'VOUT', 'VSS', 'B']
#
# ── DC Operating Point: stacked_nfet_cmirror ──
#
# 	Node                                  Voltage
# 	----                                  -------
# 	----	-------
# 	n_vout                           2.456216e-01
# 	n_vref                           8.951855e-01
# 	vdd                              3.300000e+00
#
# ✓ Converged – gf180 typical corner
